# %%
import json
import pickle

# %%
def get_friendly_name(param_name):
    return param_name#.split(".")[-2]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import cm
from collections import defaultdict
import os

def plot_function(base_string, title, is_mup, max_time=5, d_models=[256, 512, 1024, 2048], n_heads=[16], optimizer="", include_only=None, legend=True, y_maxes=None):

    
    fig, axs = plt.subplots(nrows=1, ncols=max_time, figsize=(8 * max_time, 8))
    for ax, time_step in zip(axs, range(max_time)):
        print(ax)
        per_layer_activations = defaultdict(list)

        for d_model in d_models:
            for n_head in n_heads:
                activation_json_file = os.path.join(base_string.format(d_model, n_head, optimizer), f"batch_{time_step}.pickle")

               # Open the JSON file
                with open(activation_json_file, "rb") as f:
                    print(activation_json_file)
                    data = pickle.load(f) 

                    print(data)
                    for param_name, val in data.items():
                        per_layer_activations[param_name].append(val)
        print(per_layer_activations)
    

        ax.set_title(title.format(time_step))
        cmap  = cm.get_cmap('viridis', len(per_layer_activations))
        for i, (param_name, scaled_versions) in enumerate(per_layer_activations.items()):
            if include_only:
                if include_only != param_name:
                    continue
                # continue
            ax.plot(d_models, scaled_versions, label=get_friendly_name(param_name))
        ax.set_xlabel("d_model")
        ax.set_ylabel("L1 Norm")
        ax.loglog(base=2)
        print(time_step)
        if y_maxes:
            ax.set_ylim([2**-2, 2**y_maxes[time_step]])
    
    if legend:
        axs[0].legend()

    plot_title = f"activations_{'mup' if is_mup else 'non_mup'}_max_time_{max_time}.png"

    # plt.savefig(plot_title, dpi=300)

# %%
plot_function("/root/small_2_layers_mup_official_scaled_d_model_{}_n_head_{}", "per-layer L1 Norm for muP at time {}", is_mup=True)
# Out:
# Axes(0.125,0.11;0.133621x0.77)
# /root/small_2_layers_mup_official_scaled_d_model_256_n_head_16/batch_0.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 0.07049560546875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 0.0703125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 0.09967041015625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 0.796875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 1.125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 0.2840576171875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 0.283203125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 0.2840576171875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 0.797119140625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 1.12548828125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 0.5673828125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 0.75927734375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 0.75927734375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 0.75927734375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 0.82421875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 0.82421875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.800537109375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.80078125, 'activations/l1_norm/model._fsdp_wrapped_module_output': 1.125, 'activations/l1_norm/model_output': 1.125, 'activations/l1_norm/_output': 1.125}
# /root/small_2_layers_mup_official_scaled_d_model_512_n_head_16/batch_0.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 0.0498199462890625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 0.0498046875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 0.0703125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 0.796875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 1.125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 0.27001953125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 0.26953125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 0.27001953125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 0.797119140625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 1.13134765625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 0.564697265625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 0.766845703125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 0.766845703125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 0.766845703125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 0.8203125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 0.8203125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.796875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.796875, 'activations/l1_norm/model._fsdp_wrapped_module_output': 0.56640625, 'activations/l1_norm/model_output': 0.56640625, 'activations/l1_norm/_output': 0.56640625}
# /root/small_2_layers_mup_official_scaled_d_model_1024_n_head_16/batch_0.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 0.0351715087890625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 0.03515625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 0.0498199462890625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 0.796875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 1.125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 0.2655029296875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 0.265625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 0.2655029296875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 0.796875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 1.125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 0.55859375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 0.765625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 0.765625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 0.765625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 0.81640625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 0.81640625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.796875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.796875, 'activations/l1_norm/model._fsdp_wrapped_module_output': 0.28125, 'activations/l1_norm/model_output': 0.28125, 'activations/l1_norm/_output': 0.28125}
# /root/small_2_layers_mup_official_scaled_d_model_2048_n_head_16/batch_0.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output':
, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.82421875, 'activations/l1_norm/model._fsdp_wrapped_module_output': 51.75, 'activations/l1_norm/model_output': 51.75, 'activations/l1_norm/_output': 51.75}
# /root/small_2_layers_mup_official_scaled_d_model_2048_n_head_16/batch_1.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 0.594482421875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 0.59765625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 0.714111328125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 0.784423828125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 13.03515625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 51.265625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 51.25, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 51.265625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 0.75830078125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 7.70703125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 3.80078125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 2170.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 2170.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 2170.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 2160.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 2160.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.91015625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.91015625, 'activations/l1_norm/model._fsdp_wrapped_module_output': 54.75, 'activations/l1_norm/model_output': 54.75, 'activations/l1_norm/_output': 54.75}
# defaultdict(<class 'list'>, {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': [0.594970703125, 0.59765625, 0.59765625, 0.594482421875], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': [0.59765625, 0.59765625, 0.59765625, 0.59765625], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': [0.708251953125, 0.721923828125, 0.713623046875, 0.714111328125], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': [0.87890625, 0.715087890625, 0.732177734375, 0.784423828125], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': [11.42578125, 15.9921875, 12.9609375, 13.03515625], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': [152.0, 283.375, 173.875, 51.265625], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': [152.0, 284.0, 174.0, 51.25], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': [152.0, 283.375, 173.875, 51.265625], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': [0.853515625, 0.865234375, 0.93359375, 0.75830078125], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': [14.2421875, 30.390625, 37.421875, 7.70703125], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': [7.078125, 14.7734375, 18.8671875, 3.80078125], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': [3924.0, 8222.0, 10792.0, 2170.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': [3924.0, 8222.0, 10792.0, 2170.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': [3924.0, 8222.0, 10792.0, 2170.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': [3888.0, 8320.0, 10880.0, 2160.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': [3888.0, 8320.0, 10880.0, 2160.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': [0.400390625, 0.58056640625, 0.82421875, 0.91015625], 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': [0.400390625, 0.58203125, 0.82421875, 0.91015625], 'activations/l1_norm/model._fsdp_wrapped_module_output': [2.390625, 25.125, 51.75, 54.75], 'activations/l1_norm/model_output': [2.390625, 25.125, 51.75, 54.75], 'activations/l1_norm/_output': [2.390625, 25.125, 51.75, 54.75]})
# 1
# Axes(0.44569,0.11;0.133621x0.77)
# /root/small_2_layers_mup_official_scaled_d_model_256_n_head_16/batch_2.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 0.9248046875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 0.99609375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 1.17333984375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 1.001220703125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 33.59375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 4200.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 4192.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 4200.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 1.00048828125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 85.8125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 42.640625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 39648.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 39648.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 39648.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 41216.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 41216.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.3741455078125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.373046875, 'activations/l1_norm/model._fsdp_wrapped_module_output': 56.75, 'activations/l1_norm/model_output': 56.75, 'activations/l1_norm/_output': 56.75}
# /root/small_2_layers_mup_official_scaled_d_model_512_n_head_16/batch_2.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 0.90283203125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 1.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 1.21044921875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 0.751220703125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 40.59375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 3178.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 3184.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 3178.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 0.859375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 83.4375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 42.40625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 39424.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 39424.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 39424.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 39168.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 39168.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.541748046875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.54296875, 'activations/l1_norm/model._fsdp_wrapped_module_output': 37.75, 'activations/l1_norm/model_output': 37.75, 'activations/l1_norm/_output': 37.75}
# /root/small_2_layers_mup_official_scaled_d_model_1024_n_head_16/batch_2.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 0.9326171875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 1.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 1.21142578125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 0.75048828125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 34.1875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 2571.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 2576.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 2571.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 0.9833984375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 30.859375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 15.28125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 14596.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 14596.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 14596.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 14720.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 14720.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.769775390625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0
pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 0.596923828125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 0.59765625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 0.71533203125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 0.734619140625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 51.421875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 2042.5, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 2040.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 2042.5, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 0.917724609375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 128.96875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 65.0625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 147840.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 147840.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 147840.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 148480.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 148480.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.51953125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.51953125, 'activations/l1_norm/model._fsdp_wrapped_module_output': 70.0, 'activations/l1_norm/model_output': 70.0, 'activations/l1_norm/_output': 70.0}
# /root/small_2_layers_no_mup_scaled_d_model_2048_n_head_16/batch_1.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 0.593994140625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 0.59765625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 0.712158203125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 0.78076171875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 102.5, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 3316.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 3312.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 3316.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 0.78125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 165.6875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 83.171875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 381568.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 381568.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 381568.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 380928.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 380928.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.57421875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.57421875, 'activations/l1_norm/model._fsdp_wrapped_module_output': 168.0, 'activations/l1_norm/model_output': 168.0, 'activations/l1_norm/_output': 168.0}
# defaultdict(<class 'list'>, {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': [0.594970703125, 0.5966796875, 0.596923828125, 0.593994140625], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': [0.59765625, 0.59765625, 0.59765625, 0.59765625], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': [0.708251953125, 0.720458984375, 0.71533203125, 0.712158203125], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': [0.87890625, 0.71533203125, 0.734619140625, 0.78076171875], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': [11.42578125, 31.4296875, 51.421875, 102.5], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': [152.0, 1034.75, 2042.5, 3316.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': [152.0, 1032.0, 2040.0, 3312.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': [152.0, 1034.75, 2042.5, 3316.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': [0.853515625, 0.863037109375, 0.917724609375, 0.78125], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': [14.2421875, 58.546875, 128.96875, 165.6875], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': [7.078125, 28.390625, 65.0625, 83.171875], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': [3924.0, 31592.0, 147840.0, 381568.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': [3924.0, 31592.0, 147840.0, 381568.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': [3924.0, 31592.0, 147840.0, 381568.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': [3888.0, 31872.0, 148480.0, 380928.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': [3888.0, 31872.0, 148480.0, 380928.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': [0.400390625, 0.421875, 0.51953125, 0.57421875], 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': [0.400390625, 0.421875, 0.51953125, 0.57421875], 'activations/l1_norm/model._fsdp_wrapped_module_output': [2.390625, 12.5, 70.0, 168.0], 'activations/l1_norm/model_output': [2.390625, 12.5, 70.0, 168.0], 'activations/l1_norm/_output': [2.390625, 12.5, 70.0, 168.0]})
# 1
# Axes(0.44569,0.11;0.133621x0.77)
# /root/small_2_layers_no_mup_scaled_d_model_256_n_head_16/batch_2.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 0.92236328125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 0.99609375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 1.17333984375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 1.00244140625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 33.65625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 4232.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 4224.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 4232.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 1.00048828125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 85.78125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 42.5625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 39648.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 39648.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 39648.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 41216.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 41216.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.3736572265625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.373046875, 'activations/l1_norm/model._fsdp_wrapped_module_output': 56.75, 'activations/l1_norm/model_output': 56.75, 'activations/l1_norm/_output': 56.75}
# /root/small_2_layers_no_mup_scaled_d_model_512_n_head_16/batch_2.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 0.94140625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 1.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 1.21533203125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 0.744140625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 67.90625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 4708.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 4704.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 4708.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 0.80078125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 123.46875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 61.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 114080.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 114080.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 114080.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 114176.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 114176.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.3629150390625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.36328125, 'activations/l1_norm/model._fsdp_wrapped_module_output': 28.75, 'activations/l1_norm/model_output': 28.75, 'activations/l1_norm/_output': 28.75}
# /root/small_2_layers_no_mup_scaled_d_model_1024_n_head_16/batch_2.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 0.94140625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 1.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 1.2119140625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 0.776611328125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 135.4375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 15176.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 15168.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 15176.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 0.885986328125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 73.59375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 36.4296875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 139232.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 139232.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 139232.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 138240.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 138240.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.510009765625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.51171875, 'activations/l1_norm/model._fsdp_wrapped_module_output': 138.0, 'activations/l1_norm/model_output': 138.0, 'activations/l1_norm/_output': 138.0}
# /root/small_2_layers_no_mup_scaled_d_model_2048_n_head_16/batch_2.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 0.944580078125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 0.96875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 1.21484375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 0.861083984375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 359.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 157376.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 157696.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 157376.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 0.959716796875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 970.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 483.375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 3723264.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 3723264.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 3723264.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 3768320.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 3768320.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.5859375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.5859375, 'activations/l1_norm/model._fsdp_wrapped_module_output': 184.0, 'activations/l1_norm/model_output': 184.0, 'activations/l1_norm/_output': 184.0}
# defaultdict(<class 'list'>, {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': [0.92236328125, 0.94140625, 0.94140625, 0.944580078125], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': [0.99609375, 1.0, 1.0, 0.96875], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': [1.17333984375, 1.21533203125, 1.2119140625, 1.21484375], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': [1.00244140625, 0.744140625, 0.776611328125, 0.861083984375], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': [33.65625, 67.90625, 135.4375, 359.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': [4232.0, 4708.0, 15176.0, 157376.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': [4224.0, 4704.0, 15168.0, 157696.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': [4232.0, 4708.0, 15176.0, 157376.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': [1.00048828125, 0.80078125, 0.885986328125, 0.959716796875], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': [85.78125, 123.46875, 73.59375, 970.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': [42.5625, 61.0, 36.4296875, 483.375], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': [39648.0, 114080.0, 139232.0, 3723264.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': [39648.0, 114080.0, 139232.0, 3723264.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': [39648.0, 114080.0, 139232.0, 3723264.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': [41216.0, 114176.0, 138240.0, 3768320.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': [41216.0, 114176.0, 138240.0, 3768320.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': [0.3736572265625, 0.3629150390625, 0.510009765625, 0.5859375], 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': [0.373046875, 0.36328125, 0.51171875, 0.5859375], 'activations/l1_norm/model._fsdp_wrapped_module_output': [56.75, 28.75, 138.0, 184.0], 'activations/l1_norm/model_output': [56.75, 28.75, 138.0, 184.0], 'activations/l1_norm/_output': [56.75, 28.75, 138.0, 184.0]})
# 2
# Axes(0.606034,0.11;0.133621x0.77)
# /root/small_2_layers_no_mup_scaled_d_model_256_n_head_16/batch_3.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 1.1875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 1.296875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 1.56591796875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 1.09326171875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 46.25, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 8768.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 8768.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 8768.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 1.22509765625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 166.5625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 85.65625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 104448.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 104448.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 104448.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 108032.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 108032.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.3929443359375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.392578125, 'activations/l1_norm/model._fsdp_wrapped_module_output': 64.0, 'activations/l1_norm/model_output': 64.0, 'activations/l1_norm/_output': 64.0}
# /root/small_2_layers_no_mup_scaled_d_model_512_n_head_16/batch_3.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 1.20849609375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 1.265625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 1.60693359375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 0.8271484375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 101.375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 33016.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 33024.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 33016.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 1.39794921875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 587.75, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 292.5, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 716544.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 716544.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 716544.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 724992.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 724992.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.498046875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.498046875, 'activations/l1_norm/model._fsdp_wrapped_module_output': 73.5, 'activations/l1_norm/model_output': 73.5, 'activations/l1_norm/_output': 73.5}
# /root/small_2_layers_no_mup_scaled_d_model_1024_n_head_16/batch_3.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 1.17919921875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 1.1953125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 1.5615234375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 0.902587890625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 207.625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 88192.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 88064.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 88192.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 1.375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 1012.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 512.875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 2573312.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 2573312.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 2573312.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 2555904.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 2555904.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.6953125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.6953125, 'activations/l1_norm/model._fsdp_wrapped_module_output': 214.0, 'activations/l1_norm/model_output': 214.0, 'activations/l1_norm/_output': 214.0}
# /root/small_2_layers_no_mup_scaled_d_model_2048_n_head_16/batch_3.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 1.173828125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 1.1796875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 1.56787109375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 0.95263671875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 607.5, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 353920.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 354304.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 353920.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 1.259765625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 2042.5, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 1022.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 10334208.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 10334208.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 10334208.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 10420224.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 10420224.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.6875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.6875, 'activations/l1_norm/model._fsdp_wrapped_module_output': 272.0, 'activations/l1_norm/model_output': 272.0, 'activations/l1_norm/_output': 272.0}
# defaultdict(<class 'list'>, {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': [1.1875, 1.20849609375, 1.17919921875, 1.173828125], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': [1.296875, 1.265625, 1.1953125, 1.1796875], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': [1.56591796875, 1.60693359375, 1.5615234375, 1.56787109375], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': [1.09326171875, 0.8271484375, 0.902587890625, 0.95263671875], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': [46.25, 101.375, 207.625, 607.5], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': [8768.0, 33016.0, 88192.0, 353920.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': [8768.0, 33024.0, 88064.0, 354304.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': [8768.0, 33016.0, 88192.0, 353920.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': [1.22509765625, 1.39794921875, 1.375, 1.259765625], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': [166.5625, 587.75, 1012.0, 2042.5], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': [85.65625, 292.5, 512.875, 1022.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': [104448.0, 716544.0, 2573312.0, 10334208.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': [104448.0, 716544.0, 2573312.0, 10334208.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': [104448.0, 716544.0, 2573312.0, 10334208.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': [108032.0, 724992.0, 2555904.0, 10420224.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': [108032.0, 724992.0, 2555904.0, 10420224.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': [0.3929443359375, 0.498046875, 0.6953125, 0.6875], 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': [0.392578125, 0.498046875, 0.6953125, 0.6875], 'activations/l1_norm/model._fsdp_wrapped_module_output': [64.0, 73.5, 214.0, 272.0], 'activations/l1_norm/model_output': [64.0, 73.5, 214.0, 272.0], 'activations/l1_norm/_output': [64.0, 73.5, 214.0, 272.0]})
# 3
# Axes(0.766379,0.11;0.133621x0.77)
# /root/small_2_layers_no_mup_scaled_d_model_256_n_head_16/batch_4.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 1.42578125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 1.5390625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 1.904296875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 1.17138671875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 59.734375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 17824.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 17792.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 17824.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 1.3017578125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 136.28125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 69.65625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 101568.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 101568.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 101568.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 108544.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 108544.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.328857421875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.328125, 'activations/l1_norm/model._fsdp_wrapped_module_output': 42.0, 'activations/l1_norm/model_output': 42.0, 'activations/l1_norm/_output': 42.0}
# /root/small_2_layers_no_mup_scaled_d_model_512_n_head_16/batch_4.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 1.4423828125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 1.484375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 1.947265625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 0.939208984375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 132.25, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 62176.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 62208.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 62176.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 1.63427734375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 816.75, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 409.125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 1198080.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 1198080.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 1198080.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 1220608.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 1220608.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.57421875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.57421875, 'activations/l1_norm/model._fsdp_wrapped_module_output': 104.0, 'activations/l1_norm/model_output': 104.0, 'activations/l1_norm/_output': 104.0}
# /root/small_2_layers_no_mup_scaled_d_model_1024_n_head_16/batch_4.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 1.384765625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 1.34375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 1.8583984375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 1.005126953125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 260.0625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 59776.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 59904.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 59776.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 1.42822265625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 718.5, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 320.625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 1927680.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 1927680.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 1927680.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 1916928.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 1916928.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.68359375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.68359375, 'activations/l1_norm/model._fsdp_wrapped_module_output': 83.0, 'activations/l1_norm/model_output': 83.0, 'activations/l1_norm/_output': 83.0}
# /root/small_2_layers_no_mup_scaled_d_model_2048_n_head_16/batch_4.pickle
# {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': 1.365234375, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': 1.3515625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': 1.85888671875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': 1.0361328125, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': 784.5, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': 270080.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': 270336.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': 270080.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': 1.50732421875, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': 2709.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': 1356.5, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': 16453632.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': 16453632.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': 16453632.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': 16515072.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': 16515072.0, 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': 0.75390625, 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': 0.75390625, 'activations/l1_norm/model._fsdp_wrapped_module_output': 284.0, 'activations/l1_norm/model_output': 284.0, 'activations/l1_norm/_output': 284.0}
# defaultdict(<class 'list'>, {'activations/l1_norm/model._fsdp_wrapped_module.transformer.wte_output': [1.42578125, 1.4423828125, 1.384765625, 1.365234375], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.wpe_output': [1.5390625, 1.484375, 1.34375, 1.3515625], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.emb_drop_output': [1.904296875, 1.947265625, 1.8583984375, 1.85888671875], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_1_output': [1.17138671875, 0.939208984375, 1.005126953125, 1.0361328125], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.Wqkv_output': [59.734375, 132.25, 260.0625, 784.5], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn.out_proj_output': [17824.0, 62176.0, 59776.0, 270080.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.attn_output': [17792.0, 62208.0, 59904.0, 270336.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_attn_dropout_output': [17824.0, 62176.0, 59776.0, 270080.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.norm_2_output': [1.3017578125, 1.63427734375, 1.42822265625, 1.50732421875], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.up_proj_output': [136.28125, 816.75, 718.5, 2709.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.act_output': [69.65625, 409.125, 320.625, 1356.5], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn.down_proj_output': [101568.0, 1198080.0, 1927680.0, 16453632.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.ffn_output': [101568.0, 1198080.0, 1927680.0, 16453632.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module.resid_ffn_dropout_output': [101568.0, 1198080.0, 1927680.0, 16453632.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0._fsdp_wrapped_module_output': [108544.0, 1220608.0, 1916928.0, 16515072.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.blocks.0_output': [108544.0, 1220608.0, 1916928.0, 16515072.0], 'activations/l1_norm/model._fsdp_wrapped_module.transformer.norm_f_output': [0.328857421875, 0.57421875, 0.68359375, 0.75390625], 'activations/l1_norm/model._fsdp_wrapped_module.transformer_output': [0.328125, 0.57421875, 0.68359375, 0.75390625], 'activations/l1_norm/model._fsdp_wrapped_module_output': [42.0, 104.0, 83.0, 284.0], 'activations/l1_norm/model_output': [42.0, 104.0, 83.0, 284.0], 'activations/l1_norm/_output': [42.0, 104.0, 83.0, 284.0]})
# 4
# /tmp/ipykernel_31605/482900279.py:31: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap  = cm.get_cmap('viridis', len(per_layer_activations))

# %%
plot_function("/root/large_12_layers_mup_scaled_d_model_{}_n_head_{}_optimizer_{}", "per-layer L1 Norm for muP library plot at time with 125M at time with lion w {}", d_models=[192, 384, 768], n_heads=[12],  optimizer="mup_decoupled_lionw", is_mup=True, legend=False)

# %%
plot_function("/root/large_12_layers_no_mup_scaled_d_model_{}_n_head_{}_optimizer_{}", "per-layer L1 Norm SP plot at time with 125M with lion w at time {}", d_models=[192, 384, 768, 1536], n_heads=[12],  optimizer="decoupled_lionw", is_mup=False, legend=False)
